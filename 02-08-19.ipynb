# %% [markdown]
# # exception handling

# %%
a=int(input("enter the number"))
b=int(input("enter another number"))
try:
    print(a/b)
except x as e:
    print("shld not be zero:",e)
else:
    print("else block")
finally:
    print("bye")
# Out:
# enter the numberx
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-9da33ed2fa77> in <module>
# ----> 1 a=int(input("enter the number"))
#       2 b=int(input("enter another number"))
#       3 try:
#       4     print(a/b)
#       5 except x as ze:
#
# ValueError: invalid literal for int() with base 10: 'x'

# %%
try:
    raise NameError('HiThere')
except NameError:
    print('An exception flew by!')
    raise
# Out:
# An exception flew by!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-c22481690444> in <module>
#       1 try:
# ----> 2     raise NameError('HiThere')
#       3 except NameError:
#       4     print('An exception flew by!')
#       5     raise
#
# NameError: HiThere

# %%
a=int(input("enter the number"))
b=int(input("enter another number"))
print(a/b)
try:
    print(s)
except exception as e:
    print("shld not be zero:",e)
else:
    print("else block")
finally:
    print("bye")
# Out:
# enter the number6
# enter another number0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-65-07396347d24a> in <module>
#       1 a=int(input("enter the number"))
#       2 b=int(input("enter another number"))
# ----> 3 print(a/b)
#       4 try:
#       5     print(s)
#
# ZeroDivisionError: division by zero

# %%
a=int(input("enter the number"))
if a>18 and a<80:
    print("person is eligible to vote")
else:
    try:
        if (a<0): 
            raise IOError
        print("the person is eligible to vote")
    except exception:
        print("correct age")
else:
    print(" not eligible")
# Out:
# enter the number9
# the person is not eligible to vote

# %%
from threading import *
from time import sleep
class a(Thread):
    def run(self):
        for i in range(1,10):
            print("hello")
            sleep(1)
class b(Thread):
    def run(self):
        for i in range(1,10):
            print("hii")
            sleep(1)
            
t1=a()
t1.start()
t2=b()
t2.start()
# Out:
# hello
# hii
# hello
# hii
# hello
# hii
# hello
# hii
# hello
# hii
# hello
# hii
# hello
# hii
# hello
# hii
# hello
# hii

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\LENOVO\Downloads\APPLESTORE.CSV")

# %%
df
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# 5              6   283619399
# 6              7   283646709
# 7              8   284035177
# 8              9   284666222
# 9             10   284736660
# 10            11   284791396
# 11            12   284815117
# 12            13   284815942
# 13            14   284847138
# 14            15   284862767
# 15            16   284876795
# 16            17   284882215
# 17            18   284910350
# 18            20   284993459
# 19            21   285005463
# 20            22   285946052
# 21            23   285994151
# 22            24   286058814
# 23            25   286070473
# 24            27   286799607
# 25            28   286906691
# 26            29   286911400
# 27            31   288113403
# 28            32   288120394
# 29            33   288419283
# ...          ...         ...
# ...

# %%
x=df[df.prime_genre=='Games']

# %%
y=df[df.prime_genre=='Social Networking']

# %%
import numpy as np
free=np.average(x==0)
paid=np.average(x!=0)
free1=np.average(y==0)
paid1=np.average(y!=0)
print(free,paid)
print(free1,paid1)
# Out:
# 0.07274499649678619 0.9272550035032138
# 0.14688270517787955 0.8531172948221205

# %%
df["is_free"] = df.price.apply(lambda price: True if price == 0 else False)

# %%
paid_apps = df[~df.is_free]

# %%
paid_apps[paid_apps.price > 9]
# Out:
#       Unnamed: 0          id  \
# 8              9   284666222
# 29            33   288419283
# 65            74   298206806
# 68            77   299029654
# 115          129   308368164
# 134          153   312220102
# 153          175   318304532
# 158          180   319295332
# 162          184   320279293
# 198          226   329127297
# 230          262   335545504
# 267          301   341691394
# 344          388   360593530
# 351          397   363306776
# 359          405   363738376
# 361          407   363998953
# 372          418   364502063
# 399          455   369820957
# 419          478   373493387
# 426          486   374211477
# 430          491   375295479
# 446          510   377908737
# 509          580   388633565
# 535          608   392188745
# 712          815   421168738
# 723          828   423198259
# 732          838   424591347
# 759          868   429870273
# 764          873   430234732
# 766          875   430823968
# ...          ...         ...
# ...
