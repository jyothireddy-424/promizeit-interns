# %% [markdown]
# ##  Define a function to read from a csv file using the pandas library and display the file data as output

# %%
import csv
with open(r'C:\Users\Raja\Desktop\sample.csv','r') as csv_file:
    csv_reader = csv.reader(csv_file)
        
    for line in csv_reader:
        print(line)
# Out:
# ['ï»¿First-Name', 'Last-Name', 'E-Mail', 'DOB']
# ['Raja', 'D', 'rajadsru@gmail.com', '12/6/1996']
# ['Ashok', 'K', 'arkondapati1@gmail.com', '13/10/1996']
# ['Sadiya', 'S', 'ssfathi09@gamil.com', '9/7/1996']

# %% [markdown]
# ## Define a function to add new row data to a csv file

# %%
import csv
with open('sample.csv','a',newline='') as csv_file:
    
    writer=csv.writer(csv_file)
    writer.writerow({'First-Name':'Anjali','Last-Name':'B','E-Mail':'anjaliramesh@gmail.com','DOB':'5/5/1997'})
    print(writer.writerow)
# Out:
# <built-in method writerow of _csv.writer object at 0x00000242B96D21A8>

# %% [markdown]
# ## Date:26-07-2019

# %% [markdown]
# ## Problem-1
#
# ## Compute the total number of unique apps from the dataset

# %%
import csv
import numpy as np
with open('C:/Users/Raja/Desktop/AppleStore.csv','r',encoding="utf8") as csv_file:
    csv_reader = list(csv.reader(csv_file))
    unique_list=[]
    csv_reader = np.array(csv_reader)
    a = np.array(cs)
    for i in range(1,len(csv_reader)):
        if a[i][1] not in unique_list:
            unique_list.append(b[i][1])
    print(len(unique_list))
# Out:
# 7195

# %% [markdown]
# ## Problem-2
# ## Print the Top 10 apps along with their rating based on the number of downloads(rating_count_tot)

# %%
a=[]
for i in range(0,len(df)):
    a.append(df.loc[i][5])
a.sort(reverse=True)
for i in range(0,10):
    for j in range(len(df)):
        if a[i]==df.loc[j][5]:
            print(df.loc[j][1],' ',df.loc[j][5],' ',df.loc[j][7])
# Out:
# Facebook   2974676   3.5
# Instagram   2161558   4.5
# Clash of Clans   2130805   4.5
# Temple Run   1724546   4.5
# Pandora - Music & Radio   1126879   4.0
# Pinterest   1061624   4.5
# Bible   985920   4.5
# Candy Crush Saga   961794   4.5
# Spotify Music   878563   4.5
# Angry Birds   824451   4.5

# %% [markdown]
# ## Problem-3
#
# ## Categorise the dataset based on content rating into the following
# * Number of apps with content rating 4+

# %%
import csv
import numpy as np
with open('C:/Users/Raja/Desktop/AppleStore.csv','r',encoding="utf8") as csv_file:
    csv_reader = list(csv.reader(csv_file))
    unique_list=[]
    csv_reader = np.array(csv_reader)
    a = np.array(cs)
    for i in range(1,len(csv_reader)):
        if "4+" in csv_reader[i][10]:
            unique_list.append("4+")
    print(len(unique_list))
# Out:
# 4433

# %%
import csv
import numpy as np
with open(r'C:/Users/Raja/Desktop/AppleStore.csv','r',encoding="utf8") as csv_file:
    csvreader = list(csv.reader(csv_file))
    unique_list=[]
    unique_list1=[]
    unique_list2=[]
    unique_list3=[]
    cs = np.array(csvreader)
    for i in range(1,len(cs)):
        if "4+"  in cs[i][10]:
            unique_list.append("4+")
        elif "9+" in cs[i][10]:
            unique_list1.append("9+")
        elif "12+" in cs[i][10]:
            unique_list2.append("12+")    
        else:
            unique_list3.append("17+")
    print("4+ = ",len(unique_list))
    print("9+ = ",len(unique_list1))
    print("12+ = ",len(unique_list2))
    print("17+ = ",len(unique_list3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-623f6dadaef2> in <module>()
#       2 import numpy as np
#       3 with open(r'C:/Users/Raja/Desktop/AppleStore.csv','r',encoding="utf8") as csv_file:
# ----> 4     csvreader = list(csv.reader(csv_file))
#       5     unique_list=[]
#       6     unique_list1=[]
#
# TypeError: 'list' object is not callable

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/Raja/Desktop/AppleStore.csv")
a=df['prime_genre'].value_counts()
a
# Out:
# Games                3862
# Entertainment         535
# Education             453
# Photo & Video         349
# Utilities             248
# Health & Fitness      180
# Productivity          178
# Social Networking     167
# Lifestyle             144
# Music                 138
# Shopping              122
# Sports                114
# Book                  112
# Finance               104
# Travel                 81
# News                   75
# Weather                72
# Reference              64
# Food & Drink           63
# Business               57
# Navigation             46
# Medical                23
# Catalogs               10
# Name: prime_genre, dtype: int64

# %%
list=['Games','Entertainment','Education','Photo & Video','Photo & Video','Health & Fitness','Productivity','Social Networking',
     'Lifestyle','Music','Shopping','Sports','Book','Finance','Travel','News','Weather','Referance','Food & Drink','Business',
     'Navigation','Medical','Catalogs']

# %%
plt.pie(a,labels=list,autopct="%1.1f%%",radius=1*6,textprops={'fontsize':22})
plt.show()

# %%
b=df['prime_genre'].value_counts('sports')
print(b)
# Out:
# Games                0.536612
# Entertainment        0.074337
# Education            0.062943
# Photo & Video        0.048492
# Utilities            0.034459
# Health & Fitness     0.025010
# Productivity         0.024733
# Social Networking    0.023204
# Lifestyle            0.020008
# Music                0.019175
# Shopping             0.016952
# Sports               0.015840
# Book                 0.015562
# Finance              0.014450
# Travel               0.011255
# News                 0.010421
# Weather              0.010004
# Reference            0.008893
# Food & Drink         0.008754
# Business             0.007920
# Navigation           0.006392
# Medical              0.003196
# Catalogs             0.001389
# Name: prime_genre, dtype: float64
